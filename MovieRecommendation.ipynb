# %%
# !pip install -qq convokit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.2/183.2 kB 2.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 31.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 29.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 19.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.0 MB/s eta 0:00:00
#   Building wheel for convokit (pyproject.toml) ... done
#   Building wheel for emoji (setup.py) ... done

# %%
# !pip install -qq scikit-surprise
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-surprise (setup.py) ... done

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
import convokit

# %%
# Load the Cornell Movie Dialogs Corpus
corpus = convokit.Corpus(filename=convokit.download("movie-corpus"))
# Out:
# Downloading movie-corpus to /root/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done
# No configuration file found at /root/.convokit/config.yml; writing with contents:
# # Default Backend Parameters
# db_host: localhost:27017
# data_directory: ~/.convokit/saved-corpora
# default_backend: mem

# %%
# Basic statistics
print("No. of conversations:", len(corpus.conversations))
print("No. of users:", len(corpus.speakers))
print("No. of utterances:", len(corpus.utterances))
# Out:
# No. of conversations: 83097
# No. of users: 9035
# No. of utterances: 304713

# %%
# Display information about conversations
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)
    print("Conversation ID:", convo_id)
    print("Metadata:", convo.meta)
    print("No. of utterances in conversation:", len(convo.get_utterance_ids()))
    print()
# Out:
# Streaming output truncated to the last 5000 lines.
# No. of utterances in conversation: 3
#
# Conversation ID: L62263
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62256
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 6
#
# Conversation ID: L62228
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 4
#
# Conversation ID: L62222
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62218
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62213
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62210
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62207
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62022
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62250
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 6
#
# Conversation ID: L62224
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62220
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62057
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 6
#
# Conversation ID: L62527
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 6
#
# Conversation ID: L62515
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62509
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 4
#
# Conversation ID: L62476
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 6
#
# Conversation ID: L62468
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 4
#
# Conversation ID: L62458
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62456
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62149
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 5
#
# Conversation ID: L62146
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62143
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62137
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62133
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62129
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62279
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62272
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 7
#
# Conversation ID: L62521
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62440
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62436
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62411
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62409
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62405
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62395
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62393
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62386
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 5
#
# Conversation ID: L62381
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62378
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62374
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62366
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62363
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62356
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 6
#
# Conversation ID: L62354
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62307
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62297
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 5
#
# Conversation ID: L62294
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62288
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62246
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62242
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62239
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62232
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62194
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62181
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62173
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62169
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 4
#
# Conversation ID: L62165
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62159
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 5
#
# Conversation ID: L62123
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62118
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 5
#
# Conversation ID: L62113
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62109
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 4
#
# Conversation ID: L62101
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62098
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62093
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 4
#
# Conversation ID: L62089
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62082
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 7
#
# Conversation ID: L62077
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62074
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62066
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 8
#
# Conversation ID: L62040
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 11
#
# Conversation ID: L62038
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62034
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 4
#
# Conversation ID: L62031
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62024
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 7
#
# Conversation ID: L62335
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62328
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 7
#
# Conversation ID: L62349
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62343
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 4
#
# Conversation ID: L62340
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62315
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62313
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62309
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 4
#
# Conversation ID: L62433
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62430
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID: L62426
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62423
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62420
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62473
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 3
#
# Conversation ID: L62466
# Metadata: ConvoKitMeta({'movie_idx': 'm254', 'movie_name': 'badlands', 'release_year': '1973', 'rating': '7.90', 'votes': '16753', 'genre': "['crime', 'drama', 'romance', 'thriller']"})
# No. of utterances in conversation: 2
#
# Conversation ID:
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# No. of utterances in conversation: 4
#
# Conversation ID: L666256
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# No. of utterances in conversation: 2

# %%
# Create empty lists to store data
conversation_ids = []
movie_indices = []
movie_names = []
release_years = []
ratings = []
votes = []
genres = []
num_utterances = []

# Loop through conversations and extract data
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)

    # Extract metadata from ConvoKitMeta object
    metadata = convo.meta

    # Append data to respective lists
    conversation_ids.append(convo_id)
    movie_indices.append(metadata['movie_idx'])
    movie_names.append(metadata['movie_name'])
    release_years.append(metadata['release_year'])
    ratings.append(metadata['rating'])
    votes.append(metadata['votes'])
    genres.append(metadata['genre'])
    num_utterances.append(len(convo.get_utterance_ids()))

# Create a DataFrame from the lists
data = {
    'Conversation ID': conversation_ids,
    'Movie Index': movie_indices,
    'Movie Name': movie_names,
    'Rating': ratings,
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       Conversation ID Movie Index                  Movie Name Rating
# 0               L1044          m0  10 things i hate about you   6.90
# 1                L984          m0  10 things i hate about you   6.90
# 2                L924          m0  10 things i hate about you   6.90
# 3                L870          m0  10 things i hate about you   6.90
# 4                L866          m0  10 things i hate about you   6.90
# ...               ...         ...                         ...    ...
# 83092         L666324        m616                   zulu dawn   6.40
# 83093         L666262        m616                   zulu dawn   6.40
# 83094         L666520        m616                   zulu dawn   6.40
# 83095         L666369        m616                   zulu dawn   6.40
# 83096         L666256        m616                   zulu dawn   6.40
#
# [83097 rows x 4 columns]

# %%
# Create a Reader object specifying the rating scale
reader = Reader(rating_scale=(1, 10))

# %%
# Load the dataset into Surprise format
data = df[['Conversation ID','Movie Name','Rating']]
data = Dataset.load_from_df(data, reader)

# Split the data into training and testing sets (80% train, 20% test)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# Create and train the SVD recommendation model
model = SVD()
model.fit(trainset)

# Evaluate the model on the testing data (calculate RMSE)
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.0641

# %%
# Generate recommendations for a specific user (e.g., user_id='L236416')
user_id = 'L36547'
user_movies = df[df['Conversation ID'] == user_id]['Movie Name'].unique()

# Create a list of unrated movies for the user
all_movies = df['Movie Name'].unique()
unrated_movies = np.setdiff1d(all_movies, user_movies)

# Generate predictions for unrated movies
user_recommendations = []
for movie_id in unrated_movies:
    predicted_rating = model.predict(user_id, movie_id).est
    user_recommendations.append((movie_id, predicted_rating))

    # Sort recommendations by predicted rating (highest first)
user_recommendations.sort(key=lambda x: x[1], reverse=True)

# %%
# Display the top n recommendations
top_n = 3
print(f'Top {top_n} recommendations for user {user_id}:')
for movie_id, predicted_rating in user_recommendations[:top_n]:
    print(f'Movie ID: {movie_id}, Predicted Rating: {predicted_rating:.2f}')
# Out:
# Top 3 recommendations for user L36547:
# Movie ID: neuromancer, Predicted Rating: 9.25
# Movie ID: the godfather, Predicted Rating: 9.18
# Movie ID: the godfather: part ii, Predicted Rating: 8.91
